# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt

# Cargar y procesar el dataset de Minst
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0  # Normalize pixel values

# Crear el modelo
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(128, activation='relu'),  
    Dense(10, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Entrenar el modelo 
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluar el modelo
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f'\nTest accuracy: {test_acc}')

# Visualizar el modelo 
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

print("Conclusiones:")
print("1. El modelo logra una buena precision con el conjunto de datos de mnist, lo que indica que el aprendizaje fue efectivo") 
print("2. La precision y validacion se ven bien equilibradas por lo que no se necesitaria mucho ajuste")
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2552 - accuracy: 0.9276 - val_loss: 0.1395 - val_accuracy: 0.9591
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1137 - accuracy: 0.9663 - val_loss: 0.1102 - val_accuracy: 0.9662
# Epoch 3/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0771 - accuracy: 0.9768 - val_loss: 0.0833 - val_accuracy: 0.9730
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0579 - accuracy: 0.9820 - val_loss: 0.0743 - val_accuracy: 0.9769
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0444 - accuracy: 0.9858 - val_loss: 0.0752 - val_accuracy: 0.9751
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.0752 - val_accuracy: 0.9773
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.0794 - val_accuracy: 0.9764
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0228 - accuracy: 0.9929 - val_loss: 0.0863 - val_accuracy: 0.9743
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.0788 - val_accuracy: 0.9777
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.0925 - val_accuracy: 0.9745
# 313/313 - 0s - loss: 0.0925 - accuracy: 0.9745 - 261ms/epoch - 834us/step
#
# Test accuracy: 0.9745000004768372
# Conclusiones:
# 1. El modelo logra una buena precision con el conjunto de datos de mnist, lo que indica que el aprendizaje fue efectivo
# 2. La precision y validacion se ven bien equilibradas por lo que no se necesitaria mucho ajuste
